# %%
from sklearn.datasets import make_classification
import torch

# %%
# Creating classification dataset
X, y = make_classification(
    n_samples=100,
    n_features=5,
    n_informative=3,
    n_classes=2,
    random_state=42
)

# %%
X.shape
# Out:
# (100, 5)

# %%
y.shape
# Out:
# (100,)

# %%
# Convert the data to PyTorch tensors
X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.long)

# %%
print(X.dtype)
print(y.dtype)
# Out:
# torch.float32
# torch.int64

# %% [markdown]
# ## Using dataset and dataloader classes now

# %%
from torch.utils.data import Dataset, DataLoader

# %%
class CustomDataset(Dataset):

  def __init__(self, features, labels):
    self.features = features
    self.labels = labels

  def __len__(self):
    return self.features.shape[0]

  def __getitem__(self, index):
    return self.features[index], self.labels[index]

# %%
dataset = CustomDataset(X, y)

# %%
print(len(dataset))
dataset[0]
# Out:
# 100
# (tensor([-0.5166,  0.1465,  0.7529,  1.6036,  0.7435]), tensor(1))

# %%
dataloader = DataLoader(dataset, batch_size=4, shuffle=True)

# %%
for batch_features, batch_labels in dataloader:

  print(batch_features)
  print(batch_labels)

  print('-'*100)
# Out:
# tensor([[ 1.0161, -1.0365, -0.6581, -0.6825, -0.5673],
#         [-0.0964, -0.7636,  1.6033,  1.3989, -0.5426],
#         [-0.5166,  0.1465,  0.7529,  1.6036,  0.7435],
#         [ 1.0075, -0.5209, -1.1014, -2.6269, -1.4658]])
# tensor([0, 0, 1, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.0992e+00,  2.2038e+00, -2.4403e+00,  2.1658e+00,  4.7009e+00],
#         [-2.6718e-01,  9.2133e-01, -1.7099e+00,  1.0193e+00,  2.5818e+00],
#         [-2.2590e-01,  3.4715e-01, -7.5247e-02,  3.9331e-03,  2.4225e-01],
#         [-1.1099e+00,  2.2010e+00, -1.3049e+00, -6.2117e-01,  1.6689e+00]])
# tensor([1, 1, 1, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 1.0578, -0.4715, -1.5474, -2.2207, -0.7835],
#         [-0.3376, -0.8564,  1.9923,  3.0360,  0.3805],
#         [-1.1811,  2.3531, -2.1546,  1.2266,  3.8320],
#         [ 1.4602, -0.8857, -1.9501, -2.1066, -0.6032]])
# tensor([0, 0, 1, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.1637,  0.4561, -0.2626, -3.5156, -2.2864],
#         [-0.4677, -0.0548,  1.0101,  1.7586,  0.5614],
#         [ 0.8040, -0.5058, -0.4454, -2.6512, -1.9792],
#         [-1.7863,  2.1429,  0.7830,  0.1947,  0.6721]])
# tensor([0, 1, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.3194, -1.1061,  2.7805,  2.3955, -0.8506],
#         [ 0.4829, -0.9170,  0.0627,  1.3091,  0.4875],
#         [-0.2642,  0.9006, -1.1672, -0.2637,  1.1605],
#         [-0.5356,  0.3502,  0.6031,  0.9044,  0.4225]])
# tensor([1, 0, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.2374,  0.1685, -0.7063, -1.2582, -0.3466],
#         [-1.8068,  3.3665, -2.1356,  0.3405,  3.6603],
#         [ 2.0862, -1.6177, -2.5286, -1.5150, -0.0843],
#         [-1.6956,  3.1674, -2.3323,  1.1074,  4.3015]])
# tensor([0, 1, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.1318, -0.1766, -0.7813,  1.9436,  2.0131],
#         [-1.2355,  2.5109, -1.1878, -1.7371,  0.8760],
#         [ 0.6976, -1.0113,  0.3866, -0.7763, -1.4270],
#         [ 1.8886, -1.8982, -1.8143,  0.0656,  0.4476]])
# tensor([1, 0, 0, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.0400,  0.6005, -0.7167, -2.1818, -0.8288],
#         [-1.6251,  1.9616,  0.6199,  0.3388,  0.8139],
#         [-2.0555,  2.9942, -0.1193, -0.4003,  1.3470],
#         [-1.8216,  2.2620,  0.6345,  0.1482,  0.8121]])
# tensor([0, 1, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.6525, -0.7979,  0.1778, -1.1613, -1.4540],
#         [-0.6399,  1.0008, -0.3739,  0.3145,  1.0536],
#         [ 1.4355, -1.0471, -1.3142, -2.5317, -1.5042],
#         [-2.1812,  2.7154,  0.9047, -0.2344,  0.5456]])
# tensor([0, 1, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.4093, -0.4550,  0.0214, -0.7762, -0.8562],
#         [ 0.4274, -0.1165, -0.8516, -0.7720, -0.0073],
#         [ 1.0203, -0.9369, -0.2193, -2.4452, -2.2181],
#         [-0.8282,  0.6206,  0.8124,  1.2215,  0.6496]])
# tensor([0, 0, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.7109, -0.1095,  1.9667,  1.7327, -0.2199],
#         [ 0.2925, -0.6149,  0.3389,  0.3892, -0.2794],
#         [ 0.8492, -1.3516, -0.1641,  1.4098,  0.5119],
#         [ 0.6530, -0.6837,  0.1346, -1.7525, -1.8196]])
# tensor([1, 1, 1, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.8360, -1.0101, -0.2227, -0.4137, -0.6786],
#         [-1.1501,  2.2175, -1.2229, -0.5869,  1.6413],
#         [-0.2535, -1.5621,  3.5358,  2.6898, -1.4392],
#         [-0.6259,  0.7662,  0.5110, -0.6290, -0.4784]])
# tensor([0, 0, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.2255,  0.2938, -0.2659,  0.8125,  0.9873],
#         [ 0.4843, -0.8705,  0.3551,  0.2683, -0.5192],
#         [ 0.8174, -0.5579, -0.3744, -2.6288, -2.0434],
#         [-0.9261,  0.6018,  1.1743,  1.2507,  0.3852]])
# tensor([1, 1, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.4557, -0.7326,  0.4965, -0.6894, -1.2980],
#         [ 0.6005, -0.8014,  0.1147, -0.5347, -0.9216],
#         [-0.8085,  0.4702,  1.0398,  1.3920,  0.5290],
#         [-0.5190,  0.0433,  0.9729,  1.6934,  0.5906]])
# tensor([0, 0, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.1577,  0.1765, -0.4882,  1.5161,  1.6418],
#         [-0.1503,  0.7662, -0.9330, -1.0141,  0.3289],
#         [-0.8214,  1.6506, -1.1088, -0.2271,  1.5364],
#         [ 0.7130, -0.6821, -0.1450, -1.5629, -1.4576]])
# tensor([1, 0, 0, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 1.3267, -1.5396, -1.1356,  0.9512,  0.8020],
#         [-0.2414,  1.0744, -0.7941, -2.4708, -0.7458],
#         [-1.4184,  0.8134,  2.3787,  1.0979, -0.5451],
#         [-0.5560,  1.2964, -1.7705,  1.3530,  3.0831]])
# tensor([0, 0, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.3058, -0.3106, -0.7688,  1.2414,  1.3890],
#         [ 0.6582, -0.7663,  0.1989, -1.4568, -1.6827],
#         [-0.6382,  1.6566, -2.1878,  0.9210,  3.2561],
#         [-0.1490,  0.6713, -1.0617, -0.1178,  1.0729]])
# tensor([1, 0, 1, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.6586, -0.6668, -0.7936,  0.4634,  0.6183],
#         [-1.2982,  1.6532,  0.1839,  0.5382,  1.1412],
#         [-1.1407,  2.2146, -1.5478,  0.1791,  2.4825],
#         [-0.6179,  0.8138, -0.3515,  1.2109,  1.6338]])
# tensor([0, 1, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.2644,  0.1959, -2.3197,  2.4575,  3.7846],
#         [ 0.4304, -0.1575, -0.7847, -0.7183, -0.0384],
#         [-1.0276,  1.1344,  0.9484, -0.5571, -0.5650],
#         [-1.0328,  0.8070,  1.1008,  1.0975,  0.4300]])
# tensor([1, 0, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.7048, -0.2784, -0.0366, -4.2336, -3.4004],
#         [ 2.1413, -1.9825, -2.0757, -0.9134, -0.1554],
#         [ 1.0927, -1.2451, -0.5561, -0.3242, -0.4767],
#         [-0.1320,  0.7310, -1.1989, -0.2780,  1.0849]])
# tensor([0, 0, 0, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.5539,  1.0683, -1.2759,  1.4670,  2.6734],
#         [-0.5172,  0.1667,  0.6995,  1.6209,  0.8084],
#         [-0.4097,  0.8756, -1.5915,  2.2154,  3.3947],
#         [ 3.1678, -2.3945, -4.6456, -0.6232,  1.8223]])
# tensor([1, 1, 1, 0])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.9550,  1.7681, -1.2588,  0.5805,  2.3390],
#         [-0.7940,  1.4378, -1.1519,  0.9474,  2.3688],
#         [-0.9657,  1.9243, -1.5636,  0.4952,  2.5880],
#         [-0.1686, -0.7331,  1.4388,  2.2489,  0.2585]])
# tensor([1, 1, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-0.5464,  1.5373, -0.7404, -2.8264, -0.8206],
#         [-0.1789,  0.8388, -0.8051, -1.5386, -0.1378],
#         [ 1.2893, -1.0196, -1.2523, -1.6073, -0.8205],
#         [-0.1207, -0.6747,  1.1693,  2.1702,  0.4344]])
# tensor([0, 0, 0, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[-1.4403,  2.3986, -1.0030,  0.2287,  2.2000],
#         [ 0.0480,  0.0168, -0.5580,  0.9095,  1.1414],
#         [-0.7391,  0.6150,  0.4868,  1.3241,  0.9756],
#         [-0.0564, -0.0550, -0.0769,  1.0142,  0.8166]])
# tensor([1, 1, 1, 1])
# ----------------------------------------------------------------------------------------------------
# tensor([[ 0.7601, -0.5179, -0.4809, -2.1116, -1.5399],
#         [-0.6418,  0.6731,  0.0193,  1.3295,  1.3682],
#         [ 0.3543, -0.0164, -1.1692,  0.0514,  0.9268],
#         [-0.6381,  1.5152, -1.3005, -0.4792,  1.4169]])
# tensor([0, 1, 0, 0])
# ----------------------------------------------------------------------------------------------------
